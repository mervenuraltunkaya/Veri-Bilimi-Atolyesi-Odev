# %%
name = "Mervenur Altunkaya"  
age = 22                     
department = "Yazılım Mühendisliği"  # string
city = "İstanbul"             # string
hobby = "mobil uygulama geliştirme"  # string
goal = "mobil uygulama ve veri bilimini birleştirerek çalışmak " # string

print(f"Benim adım {name}, {age} yaşındayım, {city}'da yaşıyorum. "
      f"{department} öğrencisiyim. "
      f"En çok {hobby} ile ilgileniyorum ve gelecekte {goal} istiyorum.")
# Out:
# Benim adım Mervenur Altunkaya, 22 yaşındayım, İstanbul'da yaşıyorum. Yazılım Mühendisliği öğrencisiyim. En çok mobil uygulama geliştirme ile ilgileniyorum ve gelecekte mobil uygulama ve veri bilimini birleştirerek çalışmak  istiyorum.
